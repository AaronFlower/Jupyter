% %% [markdown]
% ## Octave Tutorial 01
%
% Guided by Andrew Ng from the coursera Machine Learning.

% %%
4 + 5
% Out:
% ans =  9

% %%
1/2
% Out:
% ans =  0.50000

% %%
a = 5
% Out:
% a =  5

% %%
a ~= 5
% Out:
% ans = 0

% %%
a == 5
% Out:
% ans =  1

% %% [markdown]
% ### Variables

% %%
a = 3
% Out:
% a =  3

% %%
p = pi
% Out:
% p =  3.1416

% %%
disp(p)   % comment:
% Out:
%  3.1416

% %%
format long
disp(p)
% Out:
%  3.14159265358979

% %%
disp(sprintf('2 decimals: %0.2f', p))
% Out:
% 2 decimals: 3.14

% %% [markdown]
% ### Matrices and Vectors

% %%
A = [1 2; 3 4; 5 6]
% Out:
% A =
%
%    1   2
%    3   4
%    5   6

% %%
v = [1; 2; 3]
% Out:
% v =
%
%    1
%    2
%    3

% %%
v = 1:3
% Out:
% v =
%
%    1   2   3

% %%
v = 1:0.1:2
% Out:
% v =
%
%  Columns 1 through 4:
%
%     1.00000000000000    1.10000000000000    1.20000000000000    1.30000000000000
%
%  Columns 5 through 8:
%
%     1.40000000000000    1.50000000000000    1.60000000000000    1.70000000000000
%
%  Columns 9 through 11:
%
%     1.80000000000000    1.90000000000000    2.00000000000000

% %%
w = ones(2, 3)
% Out:
% w =
%
%    1   1   1
%    1   1   1

% %%
r = rand(1, 3)
% Out:
% r =
%
%    0.2320899801221872   0.8942626334131026   0.0442022594324916

% %%
format short
n = randn(2, 3)
% Out:
% n =
%
%   -1.306920  -0.406829  -0.632248
%   -0.973248   0.029130   0.159243

% %%
I = eye(3)
% Out:
% I =
%
% Diagonal Matrix
%
%    1   0   0
%    0   1   0
%    0   0   1

% %%
help eye
% Out:
% 'eye' is a built-in function from the file libinterp/corefcn/data.cc
%
%  -- Built-in Function:  eye (N)
%  -- Built-in Function:  eye (M, N)
%  -- Built-in Function:  eye ([M N])
%  -- Built-in Function:  eye (..., CLASS)
%      Return an identity matrix.
%
%      If invoked with a single scalar argument N, return a square NxN
%      identity matrix.
%
%      If supplied two scalar arguments (M, N), `eye' takes them to be
%      the number of rows and columns.  If given a vector with two
%      elements, `eye' uses the values of the elements as the number of
%      rows and columns, respectively.  For example:
%
%           eye (3)
%            =>  1  0  0
%                0  1  0
%                0  0  1
%
%      The following expressions all produce the same result:
%
%           eye (2)
%           ==
%           eye (2, 2)
%           ==
%           eye (size ([1, 2; 3, 4]))
%
%      The optional argument CLASS, allows `eye' to return an array of
%      the specified type, like
% ...

% %% [markdown]
% ### histgram

% %%
w = -6 + sqrt(10) * randn(1, 1000000); % semicolon to suppress output.
hist(w, 100) % second parameter for number of buckets.

% %%
who
% Out:
% Variables in the current scope:
%
% ans  w

% %%
whos
% Out:
% Variables in the current scope:
%
%    Attr Name        Size                     Bytes  Class
%    ==== ====        ====                     =====  =====
%         ans         1x5                          5  char
%         w           1x1000000              8000000  double
%
% Total is 1000005 elements using 8000005 bytes

% %% [markdown]
% ### Computing on Data
